# %%
# !source activate py36;pip install python-bittrex
# Out:
# CondaEnvironmentNotFoundError: Could not find environment: py36 .
# You can list all discoverable environments with `conda info --envs`.
#
# ...
#   Running setup.py bdist_wheel for python-bittrex ... done
#   Stored in directory: /Users/mattmccarthy/Library/Caches/pip/wheels/c5/8a/90/08c6f3bd2524813b14023c086593972d3a7d4d755952de8c86
# Successfully built python-bittrex
# ...

# %%
from bittrex import Bittrex

# %%
my_bittrex = Bittrex("abe6a28e59304f6c82acf573d309f857","67a0bfdcdace4234ba2bf6d6e3de13a2"my_bittrex.get_balance('ETH')
)  # or defaulting to v1.1 as Bittrex(None, None)
    
    #API KEYS for Bittrex: 
    #Key:abe6a28e59304f6c82acf573d309f857 
    #Secret:67a0bfdcdace4234ba2bf6d6e3de13a2

# %%
my_bittrex.get_balance('ETH')
# Out:
# {'message': '',
#  'result': {'Available': None,
#   'Balance': None,
#   'CryptoAddress': None,
#   'Currency': 'ETH',
#   'Pending': None},
#  'success': True}

# %%
 my_bittrex.get_markets()
# Out:
# {'message': '',
#  'result': [{'BaseCurrency': 'BTC',
#    'BaseCurrencyLong': 'Bitcoin',
#    'Created': '2014-02-13T00:00:00',
#    'IsActive': True,
#    'IsSponsored': None,
#    'LogoUrl': 'https://bittrexblobstorage.blob.core.windows.net/public/6defbc41-582d-47a6-bb2e-d0fa88663524.png',
#    'MarketCurrency': 'LTC',
#    'MarketCurrencyLong': 'Litecoin',
#    'MarketName': 'BTC-LTC',
#    'MinTradeSize': 0.02739726,
#    'Notice': None},
#   {'BaseCurrency': 'BTC',
#    'BaseCurrencyLong': 'Bitcoin',
#    'Created': '2014-02-13T00:00:00',
#    'IsActive': True,
#    'IsSponsored': None,
#    'LogoUrl': 'https://bittrexblobstorage.blob.core.windows.net/public/a2b8eaee-2905-4478-a7a0-246f212c64c6.png',
#    'MarketCurrency': 'DOGE',
#    'MarketCurrencyLong': 'Dogecoin',
#    'MarketName': 'BTC-DOGE',
#    'MinTradeSize': 1315.78947368,
#    'Notice': None},
#   {'BaseCurrency': 'BTC',
#    'BaseCurrencyLong': 'Bitcoin',
#    'Created': '2014-02-13T00:00:00',
# ...

# %%
import json, requests


resp = requests.get(url=url, params=params)

{
   'BaseCurrency': 'BTC',
   'BaseCurrencyLong': 'Bitcoin',
   'Created': '2014-02-13T00:00:00',
   'IsActive': True,
   'IsSponsored': None,
   'LogoUrl': 'https://bittrexblobstorage.blob.core.windows.net/public/6defbc41-582d-47a6-bb2e-d0fa88663524.png',
   'MarketCurrency': 'LTC',
   'MarketCurrencyLong': 'Litecoin',
   'MarketName': 'BTC-LTC',
   'MinTradeSize': 0.02739726,
   'Notice': None
}
